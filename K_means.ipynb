# %%
import pandas as pd

# %%
data = pd.read_csv("/content/sc1.csv", index_col="iq")
data.head()
# Out:
#      cgpa
# iq
# 88   5.13
# 113  5.90
# 93   8.36
# 97   8.27
# 110  5.45

# %%
## importing the k-means algorithm

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
kmeans.fit(data)
# Out:
# KMeans(n_clusters=4)

# %%
kmeans.cluster_centers_
# Out:
# array([[4.99207547],
#        [8.85618182],
#        [5.92638298],
#        [8.14377778]])

# %%
kmeans.labels_
# Out:
# array([0, 2, 3, 3, 0, 2, 3, 1, 2, 3, 0, 2, 3, 0, 2, 3, 2, 3, 2, 2, 3, 0,
#        3, 0, 0, 3, 0, 1, 3, 0, 1, 2, 1, 0, 3, 3, 1, 2, 0, 2, 0, 3, 3, 0,
#        1, 1, 3, 2, 3, 2, 0, 0, 1, 3, 1, 2, 2, 1, 2, 1, 2, 3, 1, 1, 0, 1,
#        1, 0, 2, 3, 2, 1, 3, 0, 2, 1, 2, 1, 0, 1, 3, 1, 2, 0, 1, 0, 1, 2,
#        1, 2, 1, 1, 3, 0, 1, 3, 1, 1, 0, 1, 2, 0, 0, 1, 0, 0, 3, 0, 1, 1,
#        3, 1, 2, 2, 3, 1, 3, 2, 1, 0, 0, 2, 3, 1, 3, 0, 3, 2, 0, 3, 3, 2,
#        0, 0, 2, 1, 2, 0, 3, 3, 3, 0, 2, 0, 0, 1, 0, 1, 2, 0, 1, 0, 1, 1,
#        0, 3, 2, 1, 2, 3, 0, 1, 2, 3, 1, 0, 2, 0, 0, 1, 1, 2, 1, 0, 0, 3,
#        1, 2, 0, 1, 1, 2, 2, 2, 3, 0, 3, 3, 1, 2, 3, 3, 0, 0, 1, 0, 1, 2,
#        2, 1], dtype=int32)

# %%
import numpy as np

# %%
unique, counts = np.unique(kmeans.labels_, return_counts=True)

# %%
dict_data = dict(zip(unique, counts))
dict_data
# Out:
# {0: 53, 1: 55, 2: 47, 3: 45}

# %%
#import seaborn as sns

# %%
#data["cluster"] = kmeans.labels_

# %%
print(data.columns)
# Out:
# Index(['cgpa', 'cluster'], dtype='object')

# %%
import seaborn as sns
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Perform K-Means clustering using just 'cgpa'
kmeans = KMeans(n_clusters=3)  # You can adjust the number of clusters
#data["cluster"] = kmeans.fit_predict(data[["cgpa"]])

# Plot the data with clusters
sns.lmplot(x='cgpa', y='cluster', data=data, hue='cluster', palette='coolwarm', height=6, aspect=1, fit_reg=False)

# Show the plot
plt.show()

# %%
kmeans.score
# Out:
# <bound method _BaseKMeans.score of KMeans(n_clusters=3)>

# %%
data
# Out:
#      cgpa  cluster
# iq
# 88   5.13        0
# 113  5.90        2
# 93   8.36        1
# 97   8.27        1
# 110  5.45        2
# ..    ...      ...
# 89   4.68        0
# 118  8.57        1
# 112  5.85        2
# 108  6.23        2
# 117  8.82        1
#
# [200 rows x 2 columns]
